# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
df.shape
# Out:
# (83439, 48)

# %%
pd.set_option('display.max_columns', 48)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df['Country']
# Out:
# 0                                                 Slovakia
# 1                                              Netherlands
# 2                                       Russian Federation
# 3                                                  Austria
# 4        United Kingdom of Great Britain and Northern I...
#                                ...
# 83434                             United States of America
# 83435                                                Benin
# 83436                             United States of America
# 83437                                               Canada
# 83438                                               Brazil
# Name: Country, Length: 83439, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
df[['Employment', 'Country']]
# Out:
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# 1                                     Student, full-time
# 2                                     Student, full-time
# 3                                     Employed full-time
# 4      Independent contractor, freelancer, or self-em...
# ...                                                  ...
# 83434                                 Employed full-time
# 83435  Independent contractor, freelancer, or self-em...
# 83436                                 Employed full-time
# 83437                                 Employed full-time
# 83438                                 Employed full-time
#
#                                                  Country
# 0                                               Slovakia
# 1                                            Netherlands
# 2                                     Russian Federation
# ...

# %%
type(df)

# Dataframe is the tabular representation of data (or 2D data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['Country'])

# Series is a row of data (or 1D data)
# Multiple series combined together can be called as a dataframe
# Out:
# pandas.core.series.Series

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv')

# %%
schema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         48 non-null     object
#  1   qname       48 non-null     object
#  2   question    48 non-null     object
#  3   force_resp  48 non-null     bool
#  4   type        48 non-null     object
#  5   selector    48 non-null     object
# dtypes: bool(1), object(5)
# memory usage: 2.0+ KB

# %%
schema_df.head()
# Out:
#      qid       qname                                           question  \
# 0  QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1  QID12    MetaInfo                                  Browser Meta Info
# 2   QID1          S1  <span style="font-size:22px; font-family: aria...
# 3   QID2  MainBranch  Which of the following options best describes ...
# 4  QID24  Employment  Which of the following best describes your cur...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %% [markdown]
# ## Selecting single / multiple Columns

# %%
schema_df['qid']
# Out:
# 0      QID16
# 1      QID12
# 2       QID1
# 3       QID2
# 4      QID24
# 5       QID6
# 6       QID7
# 7       QID9
# 8     QID190
# 9      QID25
# 10    QID149
# 11    QID276
# 12     QID32
# 13     QID34
# 14     QID31
# 15     QID29
# 16     QID50
# 17     QID51
# 18     QID52
# 19     QID61
# 20    QID233
# 21    QID262
# 22    QID263
# 23    QID264
# 24    QID265
# 25    QID275
# 26    QID274
# 27     QID71
# 28    QID243
# 29     QID91
# 30    QID266
# 31    QID100
# 32    QID101
# 33    QID102
# 34    QID106
# 35    QID267
# 36    QID268
# 37    QID121
# 38    QID127
# 39    QID122
# 40    QID153
# 41    QID136
# 42    QID126
# 43    QID124
# 44    QID125
# 45    QID131
# 46    QID132
# 47    QID133
# Name: qid, dtype: object

# %%
schema_df[['qid', 'type', 'selector']]
# Out:
#        qid    type selector
# 0    QID16      DB       TB
# 1    QID12    Meta  Browser
# 2     QID1      DB       TB
# 3     QID2      MC     SAVR
# 4    QID24      MC     MAVR
# 5     QID6      MC       DL
# 6     QID7      MC       DL
# 7     QID9      MC       DL
# 8   QID190      DB       TB
# 9    QID25      MC     SAVR
# 10  QID149      MC     MAVR
# 11  QID276      MC     MAVR
# 12   QID32      MC       DL
# 13   QID34      MC       DL
# 14   QID31      MC     MAVR
# 15   QID29      MC     MAVR
# 16   QID50      MC       SB
# 17   QID51      TE       SL
# 18   QID52      MC     MAVR
# 19   QID61      DB       TB
# 20  QID233  Matrix   Likert
# 21  QID262  Matrix   Likert
# 22  QID263  Matrix   Likert
# 23  QID264  Matrix   Likert
# 24  QID265  Matrix   Likert
# 25  QID275  Matrix   Likert
# 26  QID274  Matrix   Likert
# 27   QID71      MC     SAVR
# 28  QID243      MC     MAVR
# 29   QID91      DB       TB
# 30  QID266      MC     MAVR
# 31  QID100      MC     MAVR
# ...

# %% [markdown]
# ## Selecting single / multiple Rows

# %%
schema_df.iloc[0]
# Out:
# qid                                                       QID16
# qname                                                        S0
# question      <div><span style="font-size:19px;"><strong>Hel...
# force_resp                                                False
# type                                                         DB
# selector                                                     TB
# Name: 0, dtype: object

# %%
schema_df.iloc[[0,1,2,6,10,11]]
# Out:
#        qid       qname                                           question  \
# 0    QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1    QID12    MetaInfo                                  Browser Meta Info
# 2     QID1          S1  <span style="font-size:22px; font-family: aria...
# 6     QID7    US_State  <p>In which state or territory of the USA do y...
# 10  QID149  Age1stCode  At what age did you write your first line of c...
# 11  QID276   LearnCode  How did you learn to code? Select all that apply.
#
#     force_resp  type selector
# 0        False    DB       TB
# 1        False  Meta  Browser
# 2        False    DB       TB
# 6        False    MC       DL
# 10       False    MC     MAVR
# 11       False    MC     MAVR

# %%
schema_df.iloc[0:6]
# Out:
#      qid       qname                                           question  \
# 0  QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1  QID12    MetaInfo                                  Browser Meta Info
# 2   QID1          S1  <span style="font-size:22px; font-family: aria...
# 3   QID2  MainBranch  Which of the following options best describes ...
# 4  QID24  Employment  Which of the following best describes your cur...
# 5   QID6     Country  Where do you live? <span style="font-weight: b...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR
# 5        True    MC       DL

# %%
schema_df.iloc[0:10:2]
# Out:
#       qid       qname                                           question  \
# 0   QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 2    QID1          S1  <span style="font-size:22px; font-family: aria...
# 4   QID24  Employment  Which of the following best describes your cur...
# 6    QID7    US_State  <p>In which state or territory of the USA do y...
# 8  QID190          S2  <span style="font-size:22px; font-family: aria...
#
#    force_resp type selector
# 0       False   DB       TB
# 2       False   DB       TB
# 4       False   MC     MAVR
# 6       False   MC       DL
# 8       False   DB       TB

# %%
schema_df.loc[1]
# Out:
# qid                       QID12
# qname                  MetaInfo
# question      Browser Meta Info
# force_resp                False
# type                       Meta
# selector                Browser
# Name: 1, dtype: object

# %%
schema_df.loc[[0,4,8,10,15]]
# Out:
#        qid       qname                                           question  \
# 0    QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 4    QID24  Employment  Which of the following best describes your cur...
# 8   QID190          S2  <span style="font-size:22px; font-family: aria...
# 10  QID149  Age1stCode  At what age did you write your first line of c...
# 15   QID29     OrgSize  Approximately how many people are employed by ...
#
#     force_resp type selector
# 0        False   DB       TB
# 4        False   MC     MAVR
# 8        False   DB       TB
# 10       False   MC     MAVR
# 15       False   MC     MAVR

# %%
schema_df.loc[5:10]
# Out:
#        qid       qname                                           question  \
# 5     QID6     Country  Where do you live? <span style="font-weight: b...
# 6     QID7    US_State  <p>In which state or territory of the USA do y...
# 7     QID9  UK_Country  In which part of the United Kingdom do you liv...
# 8   QID190          S2  <span style="font-size:22px; font-family: aria...
# 9    QID25     EdLevel  Which of the following best describes the high...
# 10  QID149  Age1stCode  At what age did you write your first line of c...
#
#     force_resp type selector
# 5         True   MC       DL
# 6        False   MC       DL
# 7        False   MC       DL
# 8        False   DB       TB
# 9        False   MC     SAVR
# 10       False   MC     MAVR

# %%
schema_df.loc[2:12:2]
# Out:
#        qid       qname                                           question  \
# 2     QID1          S1  <span style="font-size:22px; font-family: aria...
# 4    QID24  Employment  Which of the following best describes your cur...
# 6     QID7    US_State  <p>In which state or territory of the USA do y...
# 8   QID190          S2  <span style="font-size:22px; font-family: aria...
# 10  QID149  Age1stCode  At what age did you write your first line of c...
# 12   QID32   YearsCode  Including any education, how many years have y...
#
#     force_resp type selector
# 2        False   DB       TB
# 4        False   MC     MAVR
# 6        False   MC       DL
# 8        False   DB       TB
# 10       False   MC     MAVR
# 12       False   MC       DL

# %% [markdown]
# ## Selecting specific Rows and specific Columns

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df.iloc[4,0]
# Out:
# 'QID24'

# %%
schema_df.iloc[2,1]
# Out:
# 'S1'

# %%
schema_df.iloc[[0,3,7,8,10,11], 0]
# Out:
# 0      QID16
# 3       QID2
# 7       QID9
# 8     QID190
# 10    QID149
# 11    QID276
# Name: qid, dtype: object

# %%
schema_df.iloc[[0,3,7,8,10,11], 4]
# Out:
# 0     DB
# 3     MC
# 7     MC
# 8     DB
# 10    MC
# 11    MC
# Name: type, dtype: object

# %%
schema_df.iloc[0:10, 4]
# Out:
# 0      DB
# 1    Meta
# 2      DB
# 3      MC
# 4      MC
# 5      MC
# 6      MC
# 7      MC
# 8      DB
# 9      MC
# Name: type, dtype: object

# %%
schema_df.iloc[0:15:3, 4]
# Out:
# 0     DB
# 3     MC
# 6     MC
# 9     MC
# 12    MC
# Name: type, dtype: object

# %%
schema_df.iloc[1, [0,1,4,5]]
# Out:
# qid            QID12
# qname       MetaInfo
# type            Meta
# selector     Browser
# Name: 1, dtype: object

# %%
schema_df.iloc[1, 0:3]
# Out:
# qid                     QID12
# qname                MetaInfo
# question    Browser Meta Info
# Name: 1, dtype: object

# %%
schema_df.iloc[[0,3,7,8,10,11], [0,1,4,5]]
# Out:
#        qid       qname type selector
# 0    QID16          S0   DB       TB
# 3     QID2  MainBranch   MC     SAVR
# 7     QID9  UK_Country   MC       DL
# 8   QID190          S2   DB       TB
# 10  QID149  Age1stCode   MC     MAVR
# 11  QID276   LearnCode   MC     MAVR

# %%
schema_df.iloc[0:15, [0,1,4,5]]
# Out:
#        qid         qname  type selector
# 0    QID16            S0    DB       TB
# 1    QID12      MetaInfo  Meta  Browser
# 2     QID1            S1    DB       TB
# 3     QID2    MainBranch    MC     SAVR
# 4    QID24    Employment    MC     MAVR
# 5     QID6       Country    MC       DL
# 6     QID7      US_State    MC       DL
# 7     QID9    UK_Country    MC       DL
# 8   QID190            S2    DB       TB
# 9    QID25       EdLevel    MC     SAVR
# 10  QID149    Age1stCode    MC     MAVR
# 11  QID276     LearnCode    MC     MAVR
# 12   QID32     YearsCode    MC       DL
# 13   QID34  YearsCodePro    MC       DL
# 14   QID31       DevType    MC     MAVR

# %%
schema_df.iloc[0:15:5, [0,1,4,5]]
# Out:
#        qid       qname type selector
# 0    QID16          S0   DB       TB
# 5     QID6     Country   MC       DL
# 10  QID149  Age1stCode   MC     MAVR

# %%
schema_df.iloc[0:15:5, 0:5]
# Out:
#        qid       qname                                           question  \
# 0    QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 5     QID6     Country  Where do you live? <span style="font-weight: b...
# 10  QID149  Age1stCode  At what age did you write your first line of c...
#
#     force_resp type
# 0        False   DB
# 5         True   MC
# 10       False   MC

# %%
schema_df
# Out:
#        qid               qname  \
# 0    QID16                  S0
# 1    QID12            MetaInfo
# 2     QID1                  S1
# 3     QID2          MainBranch
# 4    QID24          Employment
# 5     QID6             Country
# 6     QID7            US_State
# 7     QID9          UK_Country
# 8   QID190                  S2
# 9    QID25             EdLevel
# 10  QID149          Age1stCode
# 11  QID276           LearnCode
# 12   QID32           YearsCode
# 13   QID34        YearsCodePro
# 14   QID31             DevType
# 15   QID29             OrgSize
# 16   QID50            Currency
# 17   QID51           CompTotal
# 18   QID52            CompFreq
# 19   QID61                  S3
# 20  QID233            Language
# 21  QID262            Database
# 22  QID263            Platform
# 23  QID264            Webframe
# 24  QID265            MiscTech
# 25  QID275           ToolsTech
# 26  QID274      NEWCollabTools
# 27   QID71               OpSys
# 28  QID243            NEWStuck
# ...

# %%
schema_df.loc[1, 'qid']
# Out:
# 'QID12'

# %%
schema_df.loc[5, 'type']
# Out:
# 'MC'

# %%
schema_df.loc[[1,2,5,7,9], 'qname']
# Out:
# 1      MetaInfo
# 2            S1
# 5       Country
# 7    UK_Country
# 9       EdLevel
# Name: qname, dtype: object

# %%
schema_df.loc[[1,2,5,7,9], 'question']
# Out:
# 1                                    Browser Meta Info
# 2    <span style="font-size:22px; font-family: aria...
# 5    Where do you live? <span style="font-weight: b...
# 7    In which part of the United Kingdom do you liv...
# 9    Which of the following best describes the high...
# Name: question, dtype: object

# %%
schema_df.loc[0:10, 'force_resp']
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# Name: force_resp, dtype: bool

# %%
schema_df.loc[0:10:2, 'force_resp']
# Out:
# 0     False
# 2     False
# 4     False
# 6     False
# 8     False
# 10    False
# Name: force_resp, dtype: bool

# %%
schema_df.loc[5, ['qid', 'qname', 'type', 'selector']]
# Out:
# qid            QID6
# qname       Country
# type             MC
# selector         DL
# Name: 5, dtype: object

# %%
schema_df.loc[[1,2,5,7,9], ['qid', 'qname', 'type', 'selector']]
# Out:
#      qid       qname  type selector
# 1  QID12    MetaInfo  Meta  Browser
# 2   QID1          S1    DB       TB
# 5   QID6     Country    MC       DL
# 7   QID9  UK_Country    MC       DL
# 9  QID25     EdLevel    MC     SAVR

# %%
schema_df.loc[2:10, ['qid', 'qname', 'type', 'selector']]
# Out:
#        qid       qname type selector
# 2     QID1          S1   DB       TB
# 3     QID2  MainBranch   MC     SAVR
# 4    QID24  Employment   MC     MAVR
# 5     QID6     Country   MC       DL
# 6     QID7    US_State   MC       DL
# 7     QID9  UK_Country   MC       DL
# 8   QID190          S2   DB       TB
# 9    QID25     EdLevel   MC     SAVR
# 10  QID149  Age1stCode   MC     MAVR

# %%
schema_df.loc[3:15:3, ['qid', 'qname', 'type', 'selector']]
# Out:
#       qid       qname type selector
# 3    QID2  MainBranch   MC     SAVR
# 6    QID7    US_State   MC       DL
# 9   QID25     EdLevel   MC     SAVR
# 12  QID32   YearsCode   MC       DL
# 15  QID29     OrgSize   MC     MAVR

# %%
schema_df.loc[3:15:3, 'qid':'selector']
# Out:
#       qid       qname                                           question  \
# 3    QID2  MainBranch  Which of the following options best describes ...
# 6    QID7    US_State  <p>In which state or territory of the USA do y...
# 9   QID25     EdLevel  Which of the following best describes the high...
# 12  QID32   YearsCode  Including any education, how many years have y...
# 15  QID29     OrgSize  Approximately how many people are employed by ...
#
#     force_resp type selector
# 3         True   MC     SAVR
# 6        False   MC       DL
# 9        False   MC     SAVR
# 12       False   MC       DL
# 15       False   MC     MAVR

# %%
schema_df.loc[3:15:3, 'qname':'type']
# Out:
#          qname                                           question  force_resp  \
# 3   MainBranch  Which of the following options best describes ...        True
# 6     US_State  <p>In which state or territory of the USA do y...       False
# 9      EdLevel  Which of the following best describes the high...       False
# 12   YearsCode  Including any education, how many years have y...       False
# 15     OrgSize  Approximately how many people are employed by ...       False
#
#    type
# 3    MC
# 6    MC
# 9    MC
# 12   MC
# 15   MC

# %% [markdown]
# ## Indexes

# %%
info = dict (
                ID      = ['B01', 'B02', 'B03', 'B04', 'B05'],
                Name    = ['Ritvik','Animesh', 'Siddhi', 'Rohan', 'Reema'],
                Age     = [29, 32, 26, 23, 33],
                Gender  = ['M', 'M', 'F', 'M', 'F'],
                Hobbies = ['Reading', 'Games', 'Music', 'Sports', 'Blogging']
            )

# %%
user_df = pd.DataFrame(info)

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       5 non-null      object
#  1   Name     5 non-null      object
#  2   Age      5 non-null      int64
#  3   Gender   5 non-null      object
#  4   Hobbies  5 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 328.0+ bytes

# %%
user_df
# Out:
#     ID     Name  Age Gender   Hobbies
# 0  B01   Ritvik   29      M   Reading
# 1  B02  Animesh   32      M     Games
# 2  B03   Siddhi   26      F     Music
# 3  B04    Rohan   23      M    Sports
# 4  B05    Reema   33      F  Blogging

# %%
user_df['Gender'].value_counts()
# Out:
# M    3
# F    2
# Name: Gender, dtype: int64

# %%
user_df.set_index('ID')
# Out:
#         Name  Age Gender   Hobbies
# ID
# B01   Ritvik   29      M   Reading
# B02  Animesh   32      M     Games
# B03   Siddhi   26      F     Music
# B04    Rohan   23      M    Sports
# B05    Reema   33      F  Blogging

# %%
user_df

# original df didn't changed because by default inplace is false
# so until and unless we assign the operation to the same df it will not change
# user_df = user_df.set_index('ID')
# user_df.set_index('ID', inplace=True)
# Out:
#     ID     Name  Age Gender   Hobbies
# 0  B01   Ritvik   29      M   Reading
# 1  B02  Animesh   32      M     Games
# 2  B03   Siddhi   26      F     Music
# 3  B04    Rohan   23      M    Sports
# 4  B05    Reema   33      F  Blogging

# %%
user_df = user_df.set_index('ID')
user_df
# Out:
#         Name  Age Gender   Hobbies
# ID
# B01   Ritvik   29      M   Reading
# B02  Animesh   32      M     Games
# B03   Siddhi   26      F     Music
# B04    Rohan   23      M    Sports
# B05    Reema   33      F  Blogging

# %%
user_df.loc['B03']
# Out:
# Name       Siddhi
# Age            26
# Gender          F
# Hobbies     Music
# Name: B03, dtype: object

# %%
user_df.iloc[2]
# Out:
# Name       Siddhi
# Age            26
# Gender          F
# Hobbies     Music
# Name: B03, dtype: object

# %%
user_df.reset_index(inplace=True)
user_df
# Out:
#     ID     Name  Age Gender   Hobbies
# 0  B01   Ritvik   29      M   Reading
# 1  B02  Animesh   32      M     Games
# 2  B03   Siddhi   26      F     Music
# 3  B04    Rohan   23      M    Sports
# 4  B05    Reema   33      F  Blogging

# %%
user_df.loc[3,'Hobbies']
# Out:
# 'Sports'

# %%
user_df.sort_index(ascending=False)
# Out:
#     ID     Name  Age Gender   Hobbies
# 4  B05    Reema   33      F  Blogging
# 3  B04    Rohan   23      M    Sports
# 2  B03   Siddhi   26      F     Music
# 1  B02  Animesh   32      M     Games
# 0  B01   Ritvik   29      M   Reading

# %% [markdown]
# ## Filtering

# %%
user_df
# Out:
#     ID     Name  Age Gender   Hobbies
# 0  B01   Ritvik   29      M   Reading
# 1  B02  Animesh   32      M     Games
# 2  B03   Siddhi   26      F     Music
# 3  B04    Rohan   23      M    Sports
# 4  B05    Reema   33      F  Blogging

# %%
age_et_23 = user_df["Age"] == 23
age_et_23
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# Name: Age, dtype: bool

# %%
age_gt_30 = user_df['Age'] > 30
age_gt_30
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# Name: Age, dtype: bool

# %%
user_df[age_et_23]
# Out:
#     ID   Name  Age Gender Hobbies
# 3  B04  Rohan   23      M  Sports

# %%
user_df[age_gt_30]
# Out:
#     ID     Name  Age Gender   Hobbies
# 1  B02  Animesh   32      M     Games
# 4  B05    Reema   33      F  Blogging

# %%
user_df[user_df["Age"] == 23]
# Out:
#     ID   Name  Age Gender Hobbies
# 3  B04  Rohan   23      M  Sports

# %%
user_df[user_df["Age"] > 30]
# Out:
#     ID     Name  Age Gender   Hobbies
# 1  B02  Animesh   32      M     Games
# 4  B05    Reema   33      F  Blogging

# %%
user_df.loc[age_et_23]
# Out:
#     ID   Name  Age Gender Hobbies
# 3  B04  Rohan   23      M  Sports

# %%
user_df.loc[age_gt_30]
# Out:
#     ID     Name  Age Gender   Hobbies
# 1  B02  Animesh   32      M     Games
# 4  B05    Reema   33      F  Blogging

# %%
user_df.loc[age_gt_30, 'Name']
# Out:
# 1    Animesh
# 4      Reema
# Name: Name, dtype: object

# %%
user_df.loc[age_gt_30, ['ID', 'Name']]
# Out:
#     ID     Name
# 1  B02  Animesh
# 4  B05    Reema

# %%
age_lt_30_and_m = (user_df['Age'] < 30) & (user_df['Gender'] == 'M')
age_lt_30_and_m
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# 4    False
# dtype: bool

# %%
user_df.loc[age_lt_30_and_m]
# Out:
#     ID    Name  Age Gender  Hobbies
# 0  B01  Ritvik   29      M  Reading
# 3  B04   Rohan   23      M   Sports

# %%
age_gt_30_or_f = (user_df['Age'] > 30) | (user_df['Gender'] == 'F')
age_gt_30_or_f
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
user_df.loc[age_gt_30_or_f, ['ID', 'Name']]
# Out:
#     ID     Name
# 1  B02  Animesh
# 2  B03   Siddhi
# 4  B05    Reema

# %%
user_df.loc[~age_gt_30, ['ID', 'Name','Age']]
# Out:
#     ID    Name  Age
# 0  B01  Ritvik   29
# 2  B03  Siddhi   26
# 3  B04   Rohan   23

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
comptotal_gt_10k = df['CompTotal'] > 10000
comptotal_gt_10k
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434     True
# 83435     True
# 83436    False
# 83437     True
# 83438    False
# Name: CompTotal, Length: 83439, dtype: bool

# %%
df.loc[comptotal_gt_10k]
# Out:
#        ResponseId                                         MainBranch  \
# 9              10                     I am a developer by profession
# 11             12                     I am a developer by profession
# 12             13                     I am a developer by profession
# 17             18                     I am a developer by profession
# 18             19  I am not primarily a developer, but I write co...
# ...           ...                                                ...
# 83432       83433                     I am a developer by profession
# 83433       83434                     I am a developer by profession
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83437       83438                     I am a developer by profession
#
#                                               Employment  \
# 9                                     Employed full-time
# ...

# %%
df.loc[comptotal_gt_10k, ['Country', 'EdLevel', 'Age1stCode']]
# Out:
#                         Country  \
# 9                        Sweden
# 11                        Spain
# 12                      Germany
# 17                       Canada
# 18                    Singapore
# ...                         ...
# 83432                    Canada
# 83433                    Brazil
# 83434  United States of America
# 83435                     Benin
# 83437                    Canada
#
#                                                EdLevel     Age1stCode
# 9      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 11        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 12     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  11 - 17 years
# 17        Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 18          Other doctoral degree (Ph.D., Ed.D., etc.)  11 - 17 years
# ...                                                ...            ...
# 83432     Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# ...

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
countries = ['India', 'Germany', 'Canada']
filter_cond = df['Country'].isin(countries)
filter_cond
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437     True
# 83438    False
# Name: Country, Length: 83439, dtype: bool

# %%
df.loc[filter_cond,['ResponseId', 'MainBranch', 'Country']]
# Out:
#        ResponseId                              MainBranch  Country
# 8               9          I am a developer by profession    India
# 12             13          I am a developer by profession  Germany
# 17             18          I am a developer by profession   Canada
# 20             21          I am a developer by profession  Germany
# 22             23  I am a student who is learning to code    India
# ...           ...                                     ...      ...
# 83415       83416          I am a developer by profession  Germany
# 83417       83418          I am a developer by profession    India
# 83424       83425          I am a developer by profession  Germany
# 83432       83433          I am a developer by profession   Canada
# 83437       83438          I am a developer by profession   Canada
#
# [19148 rows x 3 columns]

# %%
df['LanguageHaveWorkedWith']
# Out:
# 0        C++;HTML/CSS;JavaScript;Objective-C;PHP;Swift
# 1                                    JavaScript;Python
# 2                             Assembly;C;Python;R;Rust
# 3                                JavaScript;TypeScript
# 4                       Bash/Shell;HTML/CSS;Python;SQL
#                              ...
# 83434                               Clojure;Kotlin;SQL
# 83435                                              NaN
# 83436                               Groovy;Java;Python
# 83437             Bash/Shell;JavaScript;Node.js;Python
# 83438           Delphi;Elixir;HTML/CSS;Java;JavaScript
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: object

# %%
filter_cond = df['LanguageHaveWorkedWith'].str.contains('Python', na = False)
filter_cond
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 83434    False
# 83435    False
# 83436     True
# 83437     True
# 83438    False
# Name: LanguageHaveWorkedWith, Length: 83439, dtype: bool

# %%
df.loc[filter_cond,'LanguageHaveWorkedWith']
# Out:
# 1                                        JavaScript;Python
# 2                                 Assembly;C;Python;R;Rust
# 4                           Bash/Shell;HTML/CSS;Python;SQL
# 5        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 9                                               C++;Python
#                                ...
# 83429               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83430          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83431    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83436                                   Groovy;Java;Python
# 83437                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %% [markdown]
# ## Updating Rows & Columns

# %%
user_df
# Out:
#     ID     Name  Age Gender   Hobbies
# 0  B01   Ritvik   29      M   Reading
# 1  B02  Animesh   32      M     Games
# 2  B03   Siddhi   26      F     Music
# 3  B04    Rohan   23      M    Sports
# 4  B05    Reema   33      F  Blogging

# %%
user_df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Gender', 'Hobbies'], dtype='object')

# %%
user_df.columns = ['Student_ID', 'Student_Name', 'Student_Age', 'Student_Gender', 'Student_Hobbies']
user_df.columns
# Out:
# Index(['Student_ID', 'Student_Name', 'Student_Age', 'Student_Gender',
#        'Student_Hobbies'],
#       dtype='object')

# %%
user_df
# Out:
#   Student_ID Student_Name  Student_Age Student_Gender Student_Hobbies
# 0        B01       Ritvik           29              M         Reading
# 1        B02      Animesh           32              M           Games
# 2        B03       Siddhi           26              F           Music
# 3        B04        Rohan           23              M          Sports
# 4        B05        Reema           33              F        Blogging

# %%
user_df.columns = [x.upper() for x in user_df.columns]
user_df.columns
# Out:
# Index(['STUDENT_ID', 'STUDENT_NAME', 'STUDENT_AGE', 'STUDENT_GENDER',
#        'STUDENT_HOBBIES'],
#       dtype='object')

# %%
user_df
# Out:
#   STUDENT_ID STUDENT_NAME  STUDENT_AGE STUDENT_GENDER STUDENT_HOBBIES
# 0        B01       Ritvik           29              M         Reading
# 1        B02      Animesh           32              M           Games
# 2        B03       Siddhi           26              F           Music
# 3        B04        Rohan           23              M          Sports
# 4        B05        Reema           33              F        Blogging

# %%
user_df.columns = [x.replace('_', ' ') for x in user_df.columns]
user_df.columns
# Out:
# Index(['STUDENT ID', 'STUDENT NAME', 'STUDENT AGE', 'STUDENT GENDER',
#        'STUDENT HOBBIES'],
#       dtype='object')

# %%
user_df.columns = user_df.columns.str.replace(' ', '_')
user_df.columns
# Out:
# Index(['STUDENT_ID', 'STUDENT_NAME', 'STUDENT_AGE', 'STUDENT_GENDER',
#        'STUDENT_HOBBIES'],
#       dtype='object')

# %%
user_df.rename(columns = {
                            'STUDENT_ID' : 'ID',
                            'STUDENT_HOBBIES' : 'HOBBIES'
                          }, inplace=True)
user_df.columns
# Out:
# Index(['ID', 'STUDENT_NAME', 'STUDENT_AGE', 'STUDENT_GENDER', 'HOBBIES'], dtype='object')

# %%
user_df
# Out:
#     ID STUDENT_NAME  STUDENT_AGE STUDENT_GENDER   HOBBIES
# 0  B01       Ritvik           29              M   Reading
# 1  B02      Animesh           32              M     Games
# 2  B03       Siddhi           26              F     Music
# 3  B04        Rohan           23              M    Sports
# 4  B05        Reema           33              F  Blogging

# %%
user_df.loc[3]
# Out:
# ID                   B04
# STUDENT_NAME       Rohan
# STUDENT_AGE           23
# STUDENT_GENDER         M
# HOBBIES           Sports
# Name: 3, dtype: object

# %%
user_df.loc[3] = ['B04', 'Sohan', '24', 'M', 'Hiking']
user_df
# Out:
#     ID STUDENT_NAME STUDENT_AGE STUDENT_GENDER   HOBBIES
# 0  B01       Ritvik          29              M   Reading
# 1  B02      Animesh          32              M     Games
# 2  B03       Siddhi          26              F     Music
# 3  B04        Sohan          24              M    Hiking
# 4  B05        Reema          33              F  Blogging

# %%
user_df.loc[1, ['STUDENT_NAME', 'STUDENT_AGE', 'HOBBIES']] = ['Vimlesh', '27', 'Travelling']
user_df
# Out:
#     ID STUDENT_NAME STUDENT_AGE STUDENT_GENDER     HOBBIES
# 0  B01       Ritvik          29              M     Reading
# 1  B02      Vimlesh          27              M  Travelling
# 2  B03       Siddhi          26              F       Music
# 3  B04        Sohan          24              M      Hiking
# 4  B05        Reema          33              F    Blogging

# %%
user_df.loc[4, 'STUDENT_NAME'] = 'Seema'
user_df
# Out:
#     ID STUDENT_NAME STUDENT_AGE STUDENT_GENDER     HOBBIES
# 0  B01       Ritvik          29              M     Reading
# 1  B02      Vimlesh          27              M  Travelling
# 2  B03       Siddhi          26              F       Music
# 3  B04        Sohan          24              M      Hiking
# 4  B05        Seema          33              F    Blogging

# %%
user_df['STUDENT_NAME']
# Out:
# 0     Ritvik
# 1    Vimlesh
# 2     Siddhi
# 3      Sohan
# 4      Seema
# Name: STUDENT_NAME, dtype: object

# %%
user_df['STUDENT_NAME'] = user_df['STUDENT_NAME'].str.upper()
user_df
# Out:
#     ID STUDENT_NAME STUDENT_AGE STUDENT_GENDER     HOBBIES
# 0  B01       RITVIK          29              M     Reading
# 1  B02      VIMLESH          27              M  Travelling
# 2  B03       SIDDHI          26              F       Music
# 3  B04        SOHAN          24              M      Hiking
# 4  B05        SEEMA          33              F    Blogging

# %%
user_df
# Out:
#     ID STUDENT_NAME STUDENT_AGE STUDENT_GENDER     HOBBIES
# 0  B01       RITVIK          29              M     Reading
# 1  B02      VIMLESH          27              M  Travelling
# 2  B03       SIDDHI          26              F       Music
# 3  B04        SOHAN          24              M      Hiking
# 4  B05        SEEMA          33              F    Blogging

# %% [markdown]
# ###### APPLY
# ###### (works on row / column basis of a dataframe)

# %%
user_df['STUDENT_NAME'].apply(len)
# Out:
# 0    6
# 1    7
# 2    6
# 3    5
# 4    5
# Name: STUDENT_NAME, dtype: int64

# %%
def update_name(name):
    return name.capitalize()

# %%
user_df['STUDENT_NAME'] = user_df['STUDENT_NAME'].apply(update_name)
user_df
# Out:
#     ID STUDENT_NAME STUDENT_AGE STUDENT_GENDER     HOBBIES
# 0  B01       Ritvik          29              M     Reading
# 1  B02      Vimlesh          27              M  Travelling
# 2  B03       Siddhi          26              F       Music
# 3  B04        Sohan          24              M      Hiking
# 4  B05        Seema          33              F    Blogging

# %%
user_df['HOBBIES'] = user_df['HOBBIES'].apply(lambda hobbies: hobbies.upper())
user_df
# Out:
#     ID STUDENT_NAME STUDENT_AGE STUDENT_GENDER     HOBBIES
# 0  B01       Ritvik          29              M     READING
# 1  B02      Vimlesh          27              M  TRAVELLING
# 2  B03       Siddhi          26              F       MUSIC
# 3  B04        Sohan          24              M      HIKING
# 4  B05        Seema          33              F    BLOGGING

# %%
user_df['STUDENT_AGE'] = user_df['STUDENT_AGE'].apply(lambda age: int(age) + 2)
user_df
# Out:
#     ID STUDENT_NAME  STUDENT_AGE STUDENT_GENDER     HOBBIES
# 0  B01       Ritvik           31              M     READING
# 1  B02      Vimlesh           29              M  TRAVELLING
# 2  B03       Siddhi           28              F       MUSIC
# 3  B04        Sohan           26              M      HIKING
# 4  B05        Seema           35              F    BLOGGING

# %%
user_df.apply(len)
# Out:
# ID                5
# STUDENT_NAME      5
# STUDENT_AGE       5
# STUDENT_GENDER    5
# HOBBIES           5
# dtype: int64

# %%
user_df.apply(len, axis = 1)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
user_df.apply(pd.Series.min)
# Out:
# ID                     B01
# STUDENT_NAME        Ritvik
# STUDENT_AGE             26
# STUDENT_GENDER           F
# HOBBIES           BLOGGING
# dtype: object

# %%
user_df.apply(lambda x: x.min())
# Out:
# ID                     B01
# STUDENT_NAME        Ritvik
# STUDENT_AGE             26
# STUDENT_GENDER           F
# HOBBIES           BLOGGING
# dtype: object

# %% [markdown]
# ###### APPLYMAP
# ###### (works elementwise on Dataframes)

# %%
test_df = pd.read_csv('other data.csv')
test_df
# Out:
#      Name    Department            E-Mail
# 0   Arjun  Data Science   arjun@gmail.com
# 1   Richa           IOT   richa@gmail.com
# 2   Soham  Data Science   soham@gmail.com
# 3  Neeraj           IOT  neeraj@gmail.com
# 4   Parth      Big Data   parth@gmail.com
# 5  Bhavya  Data Science  bhavya@gmail.com

# %%
test_df.applymap(len)
# Out:
#    Name  Department  E-Mail
# 0     5          12      15
# 1     5           3      15
# 2     5          12      15
# 3     6           3      16
# 4     5           8      15
# 5     6          12      16

# %%
test_df.applymap(str.lower)
# Out:
#      Name    Department            E-Mail
# 0   arjun  data science   arjun@gmail.com
# 1   richa           iot   richa@gmail.com
# 2   soham  data science   soham@gmail.com
# 3  neeraj           iot  neeraj@gmail.com
# 4   parth      big data   parth@gmail.com
# 5  bhavya  data science  bhavya@gmail.com

# %% [markdown]
# ###### MAP
# ###### (works element wise on a Series)

# %%
test_df
# Out:
#      Name    Department            E-Mail
# 0   Arjun  Data Science   arjun@gmail.com
# 1   Richa           IOT   richa@gmail.com
# 2   Soham  Data Science   soham@gmail.com
# 3  Neeraj           IOT  neeraj@gmail.com
# 4   Parth      Big Data   parth@gmail.com
# 5  Bhavya  Data Science  bhavya@gmail.com

# %%
test_df['Name'].map(
                    {
                     'Arjun' : 'Vikram',
                     'Soham' : 'Rahul',
                     'Parth' : 'Vaibhav'
                    }
                   )
# Out:
# 0     Vikram
# 1        NaN
# 2      Rahul
# 3        NaN
# 4    Vaibhav
# 5        NaN
# Name: Name, dtype: object

# %%
test_df['Name'].replace(
                        {
                         'Arjun' : 'Vikram',
                         'Soham' : 'Rahul',
                         'Parth' : 'Vaibhav'
                        }
                       )
# Out:
# 0     Vikram
# 1      Richa
# 2      Rahul
# 3     Neeraj
# 4    Vaibhav
# 5     Bhavya
# Name: Name, dtype: object

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.rename(columns = {'CompTotal' : 'Salary'})
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df['NEWOtherComms'].value_counts()
# Out:
# No     53364
# Yes    29464
# Name: NEWOtherComms, dtype: int64

# %%
df['NEWOtherComms'].map(
                    {
                     'Yes' : True,
                     'No'  : False
                    }
                   )
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 83434    False
# 83435    False
# 83436    False
# 83437    False
# 83438    False
# Name: NEWOtherComms, Length: 83439, dtype: object

# %%
df['SOAccount'].value_counts()
# Out:
# Yes                        67813
# No                         10510
# Not sure/can't remember     4202
# Name: SOAccount, dtype: int64

# %%
df['SOAccount'].replace(
                            {
                             'Yes' : True,
                             'No'  : False
                            }
                           )
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 83434    False
# 83435     True
# 83436     True
# 83437     True
# 83438     True
# Name: SOAccount, Length: 83439, dtype: object

# %% [markdown]
# ## Adding & Removing Rows / Columns

# %%
test_df
# Out:
#      Name    Department            E-Mail
# 0   Arjun  Data Science   arjun@gmail.com
# 1   Richa           IOT   richa@gmail.com
# 2   Soham  Data Science   soham@gmail.com
# 3  Neeraj           IOT  neeraj@gmail.com
# 4   Parth      Big Data   parth@gmail.com
# 5  Bhavya  Data Science  bhavya@gmail.com

# %%
test_df['Surname'] = ['Deswal', 'Sharma', 'Gupta', 'Rawat', 'Pandey', 'Mishra']

# %%
test_df
# Out:
#      Name    Department            E-Mail Surname
# 0   Arjun  Data Science   arjun@gmail.com  Deswal
# 1   Richa           IOT   richa@gmail.com  Sharma
# 2   Soham  Data Science   soham@gmail.com   Gupta
# 3  Neeraj           IOT  neeraj@gmail.com   Rawat
# 4   Parth      Big Data   parth@gmail.com  Pandey
# 5  Bhavya  Data Science  bhavya@gmail.com  Mishra

# %%
surname = test_df.pop('Surname')

# %%
surname
# Out:
# 0    Deswal
# 1    Sharma
# 2     Gupta
# 3     Rawat
# 4    Pandey
# 5    Mishra
# Name: Surname, dtype: object

# %%
test_df.insert(1, 'Surname', surname)

# %%
test_df
# Out:
#      Name Surname    Department            E-Mail
# 0   Arjun  Deswal  Data Science   arjun@gmail.com
# 1   Richa  Sharma           IOT   richa@gmail.com
# 2   Soham   Gupta  Data Science   soham@gmail.com
# 3  Neeraj   Rawat           IOT  neeraj@gmail.com
# 4   Parth  Pandey      Big Data   parth@gmail.com
# 5  Bhavya  Mishra  Data Science  bhavya@gmail.com

# %%
test_df['Full Name'] = test_df['Name'] + ' ' + test_df['Surname']

# %%
test_df
# Out:
#      Name Surname    Department            E-Mail      Full Name
# 0   Arjun  Deswal  Data Science   arjun@gmail.com   Arjun Deswal
# 1   Richa  Sharma           IOT   richa@gmail.com   Richa Sharma
# 2   Soham   Gupta  Data Science   soham@gmail.com    Soham Gupta
# 3  Neeraj   Rawat           IOT  neeraj@gmail.com   Neeraj Rawat
# 4   Parth  Pandey      Big Data   parth@gmail.com   Parth Pandey
# 5  Bhavya  Mishra  Data Science  bhavya@gmail.com  Bhavya Mishra

# %%
test_df.drop(columns = ['Name', 'Surname'])
# Out:
#      Department            E-Mail      Full Name
# 0  Data Science   arjun@gmail.com   Arjun Deswal
# 1           IOT   richa@gmail.com   Richa Sharma
# 2  Data Science   soham@gmail.com    Soham Gupta
# 3           IOT  neeraj@gmail.com   Neeraj Rawat
# 4      Big Data   parth@gmail.com   Parth Pandey
# 5  Data Science  bhavya@gmail.com  Bhavya Mishra

# %%
test_df = test_df.drop(columns = ['Name', 'Surname'])

# %%
test_df
# Out:
#      Department            E-Mail      Full Name
# 0  Data Science   arjun@gmail.com   Arjun Deswal
# 1           IOT   richa@gmail.com   Richa Sharma
# 2  Data Science   soham@gmail.com    Soham Gupta
# 3           IOT  neeraj@gmail.com   Neeraj Rawat
# 4      Big Data   parth@gmail.com   Parth Pandey
# 5  Data Science  bhavya@gmail.com  Bhavya Mishra

# %%
test_df['Full Name'].str.split(' ')
# Out:
# 0     [Arjun, Deswal]
# 1     [Richa, Sharma]
# 2      [Soham, Gupta]
# 3     [Neeraj, Rawat]
# 4     [Parth, Pandey]
# 5    [Bhavya, Mishra]
# Name: Full Name, dtype: object

# %%
test_df['Full Name'].str.split(' ', expand=True)
# Out:
#         0       1
# 0   Arjun  Deswal
# 1   Richa  Sharma
# 2   Soham   Gupta
# 3  Neeraj   Rawat
# 4   Parth  Pandey
# 5  Bhavya  Mishra

# %%
test_df[['First Name','Last Name']] = test_df['Full Name'].str.split(' ', expand=True)

# %%
test_df
# Out:
#      Department            E-Mail      Full Name First Name Last Name
# 0  Data Science   arjun@gmail.com   Arjun Deswal      Arjun    Deswal
# 1           IOT   richa@gmail.com   Richa Sharma      Richa    Sharma
# 2  Data Science   soham@gmail.com    Soham Gupta      Soham     Gupta
# 3           IOT  neeraj@gmail.com   Neeraj Rawat     Neeraj     Rawat
# 4      Big Data   parth@gmail.com   Parth Pandey      Parth    Pandey
# 5  Data Science  bhavya@gmail.com  Bhavya Mishra     Bhavya    Mishra

# %%
test_df.append(
                {
                    'First Name' : 'Vansh',
                    'Last Name'  : 'Dixit'
                },
               ignore_index=True
              )
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_19956\149566980.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_df.append(
#      Department            E-Mail      Full Name First Name Last Name
# 0  Data Science   arjun@gmail.com   Arjun Deswal      Arjun    Deswal
# 1           IOT   richa@gmail.com   Richa Sharma      Richa    Sharma
# 2  Data Science   soham@gmail.com    Soham Gupta      Soham     Gupta
# 3           IOT  neeraj@gmail.com   Neeraj Rawat     Neeraj     Rawat
# 4      Big Data   parth@gmail.com   Parth Pandey      Parth    Pandey
# 5  Data Science  bhavya@gmail.com  Bhavya Mishra     Bhavya    Mishra
# 6           NaN               NaN            NaN      Vansh     Dixit

# %%
test_df.append(
                {
                    'Department' : 'Big Data',
                    'E-Mail'     : 'varun@gmail.com',
                    'Full Name'  : 'Varun Saxena',
                    'First Name' : 'Varun',
                    'Last Name'  : 'Saxena'
                }, ignore_index=True
              )
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_19956\2028648136.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_df.append(
#      Department            E-Mail      Full Name First Name Last Name
# 0  Data Science   arjun@gmail.com   Arjun Deswal      Arjun    Deswal
# 1           IOT   richa@gmail.com   Richa Sharma      Richa    Sharma
# 2  Data Science   soham@gmail.com    Soham Gupta      Soham     Gupta
# 3           IOT  neeraj@gmail.com   Neeraj Rawat     Neeraj     Rawat
# 4      Big Data   parth@gmail.com   Parth Pandey      Parth    Pandey
# 5  Data Science  bhavya@gmail.com  Bhavya Mishra     Bhavya    Mishra
# 6      Big Data   varun@gmail.com   Varun Saxena      Varun    Saxena

# %%
new_data = dict(
                   {
                    'Department' : ['Big Data', 'IOT', 'Data Science'], 
                    'E-Mail'     : ['varun@gmail.com', 'mithilesh@gmail.com', 'atul@gmail.com'],
                    'Full Name'  : ['Varun Saxena', 'Mithilesh Kumar', 'Atul Koshta'],
                    'First Name' : ['Varun', 'Mithilesh', 'Atul'],
                    'Last Name'  : ['Saxena', 'Kumar', 'Koshta']
                   }
               )
test_df1 = pd.DataFrame(new_data)

# %%
test_df1
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 0      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 1           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh     Kumar
# 2  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta

# %%
test_df.append(test_df1, ignore_index=True, sort=False)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_19956\2776080451.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_df.append(test_df1, ignore_index=True, sort=False)
#      Department               E-Mail        Full Name First Name Last Name
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh     Kumar
# ...

# %%
test_df = test_df.append(test_df1, ignore_index=True, sort=False)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_19956\1446485174.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   test_df = test_df.append(test_df1, ignore_index=True, sort=False)

# %%
test_df
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh     Kumar
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta

# %%
test_df.drop(index = 8)
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh     Kumar

# %%
test_df.loc[7, 'Last Name'] = 'Sharma'

# %%
test_df
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh    Sharma
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta

# %%
filt = test_df['Last Name'] == 'Sharma'
test_df.drop(index = test_df.loc[filt].index)
# Out:
#      Department            E-Mail      Full Name First Name Last Name
# 0  Data Science   arjun@gmail.com   Arjun Deswal      Arjun    Deswal
# 2  Data Science   soham@gmail.com    Soham Gupta      Soham     Gupta
# 3           IOT  neeraj@gmail.com   Neeraj Rawat     Neeraj     Rawat
# 4      Big Data   parth@gmail.com   Parth Pandey      Parth    Pandey
# 5  Data Science  bhavya@gmail.com  Bhavya Mishra     Bhavya    Mishra
# 6      Big Data   varun@gmail.com   Varun Saxena      Varun    Saxena
# 8  Data Science    atul@gmail.com    Atul Koshta       Atul    Koshta

# %% [markdown]
# ## Sorting

# %%
test_df
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh    Sharma
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta

# %%
test_df.sort_values(by = 'First Name')
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh    Sharma
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena

# %%
test_df.sort_values(by = 'Department', ascending=False)
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh    Sharma
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena

# %%
test_df.sort_values(by = ['Department', 'First Name'], ascending=False)
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey

# %%
test_df.sort_values(by = ['Department', 'First Name'], ascending=[False, True]).reset_index()

# we can rearrange the index after sorting and then drop the old index column
# Out:
#    index    Department               E-Mail        Full Name First Name  \
# 0      7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh
# 1      3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj
# 2      1           IOT      richa@gmail.com     Richa Sharma      Richa
# 3      0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun
# 4      8  Data Science       atul@gmail.com      Atul Koshta       Atul
# 5      5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya
# 6      2  Data Science      soham@gmail.com      Soham Gupta      Soham
# 7      4      Big Data      parth@gmail.com     Parth Pandey      Parth
# 8      6      Big Data      varun@gmail.com     Varun Saxena      Varun
#
#   Last Name
# 0    Sharma
# 1     Rawat
# 2    Sharma
# 3    Deswal
# 4    Koshta
# 5    Mishra
# 6     Gupta
# 7    Pandey
# 8    Saxena

# %%
test_df.sort_values(by = ['Department', 'First Name'], ascending=[False, True], inplace=True)

# %%
test_df
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh    Sharma
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena

# %%
test_df.sort_index(inplace=True)

# %%
test_df
# Out:
#      Department               E-Mail        Full Name First Name Last Name
# 0  Data Science      arjun@gmail.com     Arjun Deswal      Arjun    Deswal
# 1           IOT      richa@gmail.com     Richa Sharma      Richa    Sharma
# 2  Data Science      soham@gmail.com      Soham Gupta      Soham     Gupta
# 3           IOT     neeraj@gmail.com     Neeraj Rawat     Neeraj     Rawat
# 4      Big Data      parth@gmail.com     Parth Pandey      Parth    Pandey
# 5  Data Science     bhavya@gmail.com    Bhavya Mishra     Bhavya    Mishra
# 6      Big Data      varun@gmail.com     Varun Saxena      Varun    Saxena
# 7           IOT  mithilesh@gmail.com  Mithilesh Kumar  Mithilesh    Sharma
# 8  Data Science       atul@gmail.com      Atul Koshta       Atul    Koshta

# %%
test_df['First Name'].sort_values()
# Out:
# 0        Arjun
# 8         Atul
# 5       Bhavya
# 7    Mithilesh
# 3       Neeraj
# 4        Parth
# 1        Richa
# 2        Soham
# 6        Varun
# Name: First Name, dtype: object

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.sort_values(by = ['Country', 'CompTotal'], ascending=[True, False])
# Out:
#        ResponseId                              MainBranch  \
# 65399       65400          I am a developer by profession
# 22666       22667          I am a developer by profession
# 27198       27199          I am a developer by profession
# 31086       31087          I am a developer by profession
# 44640       44641          I am a developer by profession
# ...           ...                                     ...
# 75693       75694  I am a student who is learning to code
# 76082       76083          I am a developer by profession
# 79301       79302  I am a student who is learning to code
# 80996       80997             I code primarily as a hobby
# 82406       82407  I am a student who is learning to code
#
#                                               Employment      Country  \
# 65399                                 Employed full-time  Afghanistan
# 22666  Independent contractor, freelancer, or self-em...  Afghanistan
# ...

# %%
df['CompTotal'].nlargest(10)
# Out:
# 6378     1.000000e+74
# 18919    8.000000e+52
# 62417    7.000000e+39
# 103      1.000000e+29
# 23552    1.000000e+25
# 45850    6.675636e+15
# 69035    4.162026e+15
# 39571    5.474577e+10
# 82156    3.500000e+10
# 37018    1.000000e+10
# Name: CompTotal, dtype: float64

# %%
df.nlargest(10, 'CompTotal')
# Out:
#        ResponseId                                         MainBranch  \
# 6378         6379                     I am a developer by profession
# 18919       18920                     I am a developer by profession
# 62417       62418                     I am a developer by profession
# 103           104                     I am a developer by profession
# 23552       23553  I am not primarily a developer, but I write co...
# 45850       45851                     I am a developer by profession
# 69035       69036                     I am a developer by profession
# 39571       39572                     I am a developer by profession
# 82156       82157                     I am a developer by profession
# 37018       37019                     I am a developer by profession
#
#                                               Employment  \
# 6378                                  Employed full-time
# 18919                                 Employed full-time
# ...

# %% [markdown]
# ## Grouping & Aggregating

# %%
df.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
df['CompTotal'].median()
# Out:
# 67000.0

# %%
df.median()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_19956\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# ResponseId             41720.0
# CompTotal              67000.0
# ConvertedCompYearly    56211.0
# dtype: float64

# %%
df['CompTotal'].count()
# Out:
# 47183

# %%
df['SOAccount'].value_counts()
# Out:
# Yes                        67813
# No                         10510
# Not sure/can't remember     4202
# Name: SOAccount, dtype: int64

# %%
df['SOAccount'].value_counts(normalize=True)
# Out:
# Yes                        0.821727
# No                         0.127355
# Not sure/can't remember    0.050918
# Name: SOAccount, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
country_grp.get_group('India')['SOAccount'].value_counts(normalize=True)
# Out:
# Yes                        0.873501
# No                         0.081431
# Not sure/can't remember    0.045068
# Name: SOAccount, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]
# Out:
#        ResponseId                              MainBranch          Employment  \
# 8               9          I am a developer by profession  Employed part-time
# 22             23  I am a student who is learning to code  Student, full-time
# 39             40  I am a student who is learning to code  Student, part-time
# 49             50  I am a student who is learning to code  Student, full-time
# 52             53          I am a developer by profession  Employed full-time
# ...           ...                                     ...                 ...
# 83399       83400          I am a developer by profession  Employed full-time
# 83406       83407  I am a student who is learning to code  Student, full-time
# 83410       83411  I am a student who is learning to code  Student, part-time
# 83411       83412          I am a developer by profession  Employed full-time
# 83417       83418          I am a developer by profession  Student, full-time
#
# ...

# %%
df.loc[filt]['SOAccount'].value_counts(normalize=True)
# Out:
# Yes                        0.873501
# No                         0.081431
# Not sure/can't remember    0.045068
# Name: SOAccount, dtype: float64

# %%
country_grp['SOAccount'].value_counts()
# Out:
# Country      SOAccount
# Afghanistan  Yes                        39
#              No                         11
#              Not sure/can't remember     7
# Albania      Yes                        56
#              No                         10
#                                         ..
# Zambia       Not sure/can't remember     2
#              No                          1
# Zimbabwe     Yes                        28
#              Not sure/can't remember     5
#              No                          2
# Name: SOAccount, Length: 461, dtype: int64

# %%
country_grp['SOAccount'].value_counts().loc['India']
# Out:
# SOAccount
# Yes                        9032
# No                          842
# Not sure/can't remember     466
# Name: SOAccount, dtype: int64

# %%
country_grp['CompTotal'].median()
# Out:
# Country
# Afghanistan                                63000.0
# Albania                                   100000.0
# Algeria                                    60000.0
# Andorra                                    87000.0
# Angola                                    130000.0
#                                            ...
# Venezuela, Bolivarian Republic of...        1000.0
# Viet Nam                                18000000.0
# Yemen                                        300.0
# Zambia                                     12000.0
# Zimbabwe                                     600.0
# Name: CompTotal, Length: 181, dtype: float64

# %%
country_grp['CompTotal'].median().loc['India']
# Out:
# 622000.0

# %%
country_grp['CompTotal'].agg(['median', 'mean'])
# Out:
#                                           median          mean
# Country
# Afghanistan                              63000.0  5.845616e+05
# Albania                                 100000.0  2.504897e+06
# Algeria                                  60000.0  1.791122e+05
# Andorra                                  87000.0  9.892500e+04
# Angola                                  130000.0  3.387364e+05
# ...                                          ...           ...
# Venezuela, Bolivarian Republic of...      1000.0  5.110863e+07
# Viet Nam                              18000000.0  5.330125e+07
# Yemen                                      300.0  8.436429e+04
# Zambia                                   12000.0  3.455264e+04
# Zimbabwe                                   600.0  1.135846e+03
#
# [181 rows x 2 columns]

# %%
country_grp['CompTotal'].agg(['median', 'mean']).loc['India']
# Out:
# median    6.220000e+05
# mean      2.052335e+49
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
# country_grp['LanguageHaveWorkedWith'].str.contains('Python').sum()

# the above code will not work as str works on series objects but here this is a seriesgroupby object so we have to use apply method here

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
country_wise_respondants = df['Country'].value_counts()
country_wise_respondants
# Out:
# United States of America                                15288
# India                                                   10511
# Germany                                                  5625
# United Kingdom of Great Britain and Northern Ireland     4475
# Canada                                                   3012
#                                                         ...
# Saint Kitts and Nevis                                       1
# Dominica                                                    1
# Saint Vincent and the Grenadines                            1
# Tuvalu                                                      1
# Papua New Guinea                                            1
# Name: Country, Length: 181, dtype: int64

# %%
country_wise_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_wise_python
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
python_df = pd.concat([country_wise_respondants, country_wise_python], axis = 1, sort = False)

# %%
python_df
# Out:
#                                                     Country  \
# United States of America                              15288
# India                                                 10511
# Germany                                                5625
# United Kingdom of Great Britain and Northern Ir...     4475
# Canada                                                 3012
# ...                                                     ...
# Saint Kitts and Nevis                                     1
# Dominica                                                  1
# Saint Vincent and the Grenadines                          1
# Tuvalu                                                    1
# Papua New Guinea                                          1
#
#                                                     LanguageHaveWorkedWith
# United States of America                                              7975
# India                                                                 5233
# ...

# %%
python_df.rename(columns= {
                            'Country'                : 'Num_Respondants',
                            'LanguageHaveWorkedWith' : 'Num_Knows_Python'
                          }, inplace=True
                )

# %%
python_df
# Out:
#                                                     Num_Respondants  \
# United States of America                                      15288
# India                                                         10511
# Germany                                                        5625
# United Kingdom of Great Britain and Northern Ir...             4475
# Canada                                                         3012
# ...                                                             ...
# Saint Kitts and Nevis                                             1
# Dominica                                                          1
# Saint Vincent and the Grenadines                                  1
# Tuvalu                                                            1
# Papua New Guinea                                                  1
#
#                                                     Num_Knows_Python
# United States of America                                        7975
# ...

# %%
python_df['Pct_Knows_Python'] = 100 * (python_df['Num_Knows_Python'] / python_df['Num_Respondants'])

# %%
python_df
# Out:
#                                                     Num_Respondants  \
# United States of America                                      15288
# India                                                         10511
# Germany                                                        5625
# United Kingdom of Great Britain and Northern Ir...             4475
# Canada                                                         3012
# ...                                                             ...
# Saint Kitts and Nevis                                             1
# Dominica                                                          1
# Saint Vincent and the Grenadines                                  1
# Tuvalu                                                            1
# Papua New Guinea                                                  1
#
#                                                     Num_Knows_Python  \
# United States of America                                        7975
# ...

# %%
python_df.sort_values(by = 'Pct_Knows_Python', ascending=False, inplace=True)

# %%
python_df
# Out:
#                                   Num_Respondants  Num_Knows_Python  \
# Tuvalu                                          1                 1
# Brunei Darussalam                               1                 1
# Sierra Leone                                    2                 2
# Dominica                                        1                 1
# Liechtenstein                                   1                 1
# ...                                           ...               ...
# Mali                                            2                 0
# Saint Kitts and Nevis                           1                 0
# Saint Vincent and the Grenadines                1                 0
# Lesotho                                         4                 0
# Papua New Guinea                                1                 0
#
#                                   Pct_Knows_Python
# Tuvalu                                       100.0
# ...

# %%
python_df.loc['India']
# Out:
# Num_Respondants     10511.000000
# Num_Knows_Python     5233.000000
# Pct_Knows_Python       49.785939
# Name: India, dtype: float64

# %% [markdown]
# ## Cleaning Data

# %%
import numpy as np

# %%
random_data = dict (
                        First_Name = ['Ayesha', 'Ranbir', 'John', 'Katrina', np.nan, None, 'NA'],
                        Last_Name  = ['Takia', 'Kapoor', 'Abrahim', 'Kaif', np.nan, np.nan, 'Missing'],
                        E_Mail     = ['ayesha@gmail.com', 'ranbir@gmail.com', 'john@gmail.com', None, np.nan, 'anonymous@gmail.com', 'NA'],
                        Age        = [33, 55, 63, 36, None, None, 'Missing']
                   )

# %%
people_df = pd.DataFrame(random_data)

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First_Name  5 non-null      object
#  1   Last_Name   5 non-null      object
#  2   E_Mail      5 non-null      object
#  3   Age         5 non-null      object
# dtypes: object(4)
# memory usage: 352.0+ bytes

# %%
people_df
# Out:
#   First_Name Last_Name               E_Mail      Age
# 0     Ayesha     Takia     ayesha@gmail.com       33
# 1     Ranbir    Kapoor     ranbir@gmail.com       55
# 2       John   Abrahim       john@gmail.com       63
# 3    Katrina      Kaif                 None       36
# 4        NaN       NaN                  NaN     None
# 5       None       NaN  anonymous@gmail.com     None
# 6         NA   Missing                   NA  Missing

# %%
people_df.dropna()
# Out:
#   First_Name Last_Name            E_Mail      Age
# 0     Ayesha     Takia  ayesha@gmail.com       33
# 1     Ranbir    Kapoor  ranbir@gmail.com       55
# 2       John   Abrahim    john@gmail.com       63
# 6         NA   Missing                NA  Missing

# %%
people_df.dropna(axis = 0, how = 'any')
# Out:
#   First_Name Last_Name            E_Mail      Age
# 0     Ayesha     Takia  ayesha@gmail.com       33
# 1     Ranbir    Kapoor  ranbir@gmail.com       55
# 2       John   Abrahim    john@gmail.com       63
# 6         NA   Missing                NA  Missing

# %%
people_df.dropna(axis = 0, how = 'all')
# Out:
#   First_Name Last_Name               E_Mail      Age
# 0     Ayesha     Takia     ayesha@gmail.com       33
# 1     Ranbir    Kapoor     ranbir@gmail.com       55
# 2       John   Abrahim       john@gmail.com       63
# 3    Katrina      Kaif                 None       36
# 5       None       NaN  anonymous@gmail.com     None
# 6         NA   Missing                   NA  Missing

# %%
people_df.dropna(axis = 1, how = 'all')
# Out:
#   First_Name Last_Name               E_Mail      Age
# 0     Ayesha     Takia     ayesha@gmail.com       33
# 1     Ranbir    Kapoor     ranbir@gmail.com       55
# 2       John   Abrahim       john@gmail.com       63
# 3    Katrina      Kaif                 None       36
# 4        NaN       NaN                  NaN     None
# 5       None       NaN  anonymous@gmail.com     None
# 6         NA   Missing                   NA  Missing

# %%
people_df.dropna(axis = 0, how = 'any', subset = ['E_Mail'])
# Out:
#   First_Name Last_Name               E_Mail      Age
# 0     Ayesha     Takia     ayesha@gmail.com       33
# 1     Ranbir    Kapoor     ranbir@gmail.com       55
# 2       John   Abrahim       john@gmail.com       63
# 5       None       NaN  anonymous@gmail.com     None
# 6         NA   Missing                   NA  Missing

# %%
people_df.dropna(axis = 0, how = 'any', subset = ['Last_Name', 'E_Mail'])
# Out:
#   First_Name Last_Name            E_Mail      Age
# 0     Ayesha     Takia  ayesha@gmail.com       33
# 1     Ranbir    Kapoor  ranbir@gmail.com       55
# 2       John   Abrahim    john@gmail.com       63
# 6         NA   Missing                NA  Missing

# %%
people_df.dropna(axis = 0, how = 'all', subset = ['Last_Name', 'E_Mail'])
# Out:
#   First_Name Last_Name               E_Mail      Age
# 0     Ayesha     Takia     ayesha@gmail.com       33
# 1     Ranbir    Kapoor     ranbir@gmail.com       55
# 2       John   Abrahim       john@gmail.com       63
# 3    Katrina      Kaif                 None       36
# 5       None       NaN  anonymous@gmail.com     None
# 6         NA   Missing                   NA  Missing

# %%
people_df.replace('NA', np.nan, inplace = True)

# %%
people_df
# Out:
#   First_Name Last_Name               E_Mail      Age
# 0     Ayesha     Takia     ayesha@gmail.com       33
# 1     Ranbir    Kapoor     ranbir@gmail.com       55
# 2       John   Abrahim       john@gmail.com       63
# 3    Katrina      Kaif                 None       36
# 4        NaN       NaN                  NaN     None
# 5       None       NaN  anonymous@gmail.com     None
# 6        NaN   Missing                  NaN  Missing

# %%
people_df.replace('Missing', np.nan, inplace = True)

# %%
people_df
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 3    Katrina      Kaif                 None  36.0
# 4        NaN       NaN                  NaN   NaN
# 5       None       NaN  anonymous@gmail.com   NaN
# 6        NaN       NaN                  NaN   NaN

# %%
people_df.dropna(how = 'all')
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 3    Katrina      Kaif                 None  36.0
# 5       None       NaN  anonymous@gmail.com   NaN

# %%
people_df.dropna()
# Out:
#   First_Name Last_Name            E_Mail   Age
# 0     Ayesha     Takia  ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor  ranbir@gmail.com  55.0
# 2       John   Abrahim    john@gmail.com  63.0

# %%
people_df.dropna(subset=['E_Mail'])
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 5       None       NaN  anonymous@gmail.com   NaN

# %%
people_df.dropna(subset=['Last_Name', 'E_Mail'])
# Out:
#   First_Name Last_Name            E_Mail   Age
# 0     Ayesha     Takia  ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor  ranbir@gmail.com  55.0
# 2       John   Abrahim    john@gmail.com  63.0

# %%
people_df.dropna(how = 'all', subset=['Last_Name', 'E_Mail'])
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 3    Katrina      Kaif                 None  36.0
# 5       None       NaN  anonymous@gmail.com   NaN

# %%
people_df.isna()
# Out:
#    First_Name  Last_Name  E_Mail    Age
# 0       False      False   False  False
# 1       False      False   False  False
# 2       False      False   False  False
# 3       False      False    True  False
# 4        True       True    True   True
# 5        True       True   False   True
# 6        True       True    True   True

# %%
people_df['Age'].isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# Name: Age, dtype: bool

# %%
people_df['Age'].isna().value_counts(normalize=True)
# Out:
# False    0.571429
# True     0.428571
# Name: Age, dtype: float64

# %%
people_df
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 3    Katrina      Kaif                 None  36.0
# 4        NaN       NaN                  NaN   NaN
# 5       None       NaN  anonymous@gmail.com   NaN
# 6        NaN       NaN                  NaN   NaN

# %%
people_df.fillna('Missing')
# Out:
#   First_Name Last_Name               E_Mail      Age
# 0     Ayesha     Takia     ayesha@gmail.com     33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com     55.0
# 2       John   Abrahim       john@gmail.com     63.0
# 3    Katrina      Kaif              Missing     36.0
# 4    Missing   Missing              Missing  Missing
# 5    Missing   Missing  anonymous@gmail.com  Missing
# 6    Missing   Missing              Missing  Missing

# %%
people_df.fillna(0)
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 3    Katrina      Kaif                    0  36.0
# 4          0         0                    0   0.0
# 5          0         0  anonymous@gmail.com   0.0
# 6          0         0                    0   0.0

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First_Name  4 non-null      object
#  1   Last_Name   4 non-null      object
#  2   E_Mail      4 non-null      object
#  3   Age         4 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
people_df['Age'] = people_df['Age'].astype(str)

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First_Name  4 non-null      object
#  1   Last_Name   4 non-null      object
#  2   E_Mail      4 non-null      object
#  3   Age         7 non-null      object
# dtypes: object(4)
# memory usage: 352.0+ bytes

# %%
people_df['Age'] = people_df['Age'].astype(float)

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First_Name  4 non-null      object
#  1   Last_Name   4 non-null      object
#  2   E_Mail      4 non-null      object
#  3   Age         4 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
people_df['Age'] = people_df['Age'].fillna(0)

# %%
people_df
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 3    Katrina      Kaif                 None  36.0
# 4        NaN       NaN                  NaN   0.0
# 5       None       NaN  anonymous@gmail.com   0.0
# 6        NaN       NaN                  NaN   0.0

# %%
people_df['Age'] = people_df['Age'].astype(int)

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First_Name  4 non-null      object
#  1   Last_Name   4 non-null      object
#  2   E_Mail      4 non-null      object
#  3   Age         7 non-null      int32
# dtypes: int32(1), object(3)
# memory usage: 324.0+ bytes

# %%
people_df
# Out:
#   First_Name Last_Name               E_Mail  Age
# 0     Ayesha     Takia     ayesha@gmail.com   33
# 1     Ranbir    Kapoor     ranbir@gmail.com   55
# 2       John   Abrahim       john@gmail.com   63
# 3    Katrina      Kaif                 None   36
# 4        NaN       NaN                  NaN    0
# 5       None       NaN  anonymous@gmail.com    0
# 6        NaN       NaN                  NaN    0

# %%
people_df['Age'] = people_df['Age'].replace(0, np.nan)

# %%
people_df
# Out:
#   First_Name Last_Name               E_Mail   Age
# 0     Ayesha     Takia     ayesha@gmail.com  33.0
# 1     Ranbir    Kapoor     ranbir@gmail.com  55.0
# 2       John   Abrahim       john@gmail.com  63.0
# 3    Katrina      Kaif                 None  36.0
# 4        NaN       NaN                  NaN   NaN
# 5       None       NaN  anonymous@gmail.com   NaN
# 6        NaN       NaN                  NaN   NaN

# %%
people_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   First_Name  4 non-null      object
#  1   Last_Name   4 non-null      object
#  2   E_Mail      4 non-null      object
#  3   Age         4 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
people_df['Age'].mean()
# Out:
# 46.75

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
df['YearsCode'].value_counts()
# Out:
# 5                     6190
# 10                    6067
# 6                     5565
# 4                     5049
# 7                     4940
# 8                     4714
# 3                     4449
# 15                    3625
# 20                    3419
# 2                     3342
# 12                    3188
# 9                     3009
# 11                    2344
# 13                    2016
# 25                    1984
# 14                    1813
# 1                     1695
# 30                    1660
# 16                    1491
# Less than 1 year      1489
# 18                    1386
# 17                    1331
# 35                    1007
# 22                     941
# 21                     863
# 40                     830
# 23                     811
# 19                     659
# 24                     639
# 26                     533
# 27                     492
# 28                     455
# 38                     361
# 32                     331
# ...

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38',
#        'More than 50 years', '27', '41', '42', '35', '23', '28', '11',
#        '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 0, '22', '2', '1', '34',
#        '21', '13', '25', '24', '30', '31', '18', '38', 51, '27', '41',
#        '42', '35', '23', '28', '11', '37', '44', '43', '36', '33', '45',
#        '29', '50', '46', '32', '47', '49', '48'], dtype=object)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].dtype
# Out:
# dtype('float64')

# %%
df['YearsCode'].mean()
# Out:
# 12.338200169032717

# %%
df['YearsCode'].median()
# Out:
# 10.0

# %% [markdown]
# ## Dates & TimeSeries Data

# %%
eth_df = pd.read_csv('ETH_1h.csv')

# %%
eth_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23674 entries, 0 to 23673
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    23674 non-null  object
#  1   Symbol  23674 non-null  object
#  2   Open    23674 non-null  float64
#  3   High    23674 non-null  float64
#  4   Low     23674 non-null  float64
#  5   Close   23674 non-null  float64
#  6   Volume  23674 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.3+ MB

# %%
eth_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
# eth_df.loc[0, 'Date'].day_name()
# this method will not work as date column contains string object and not datetime object


# pd.to_datetime(eth_df['Date'])
# this will not convert into datetime object directly so we have to specify the specific format of the string

# %%
eth_df['Date'] = pd.to_datetime(eth_df['Date'], format = '%Y-%m-%d %I-%p')
eth_df.dtypes
# Out:
# Date      datetime64[ns]
# Symbol            object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
eth_df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
eth_df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
eth_df['Date'].dt.day_name()

# day_name method works on datetime object hence we have to call the dt class to make it work on a series object
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
eth_df['Day of Week'] = eth_df['Date'].dt.day_name()
eth_df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       Day of Week
# ...

# %%
eth_df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
eth_df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
eth_df['Date'].max() - eth_df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = eth_df['Date'] >= '2020'
eth_df.loc[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 1748 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#      Day of Week
# 0         Friday
# ...

# %%
filt = (eth_df['Date'] >= '2019') & (eth_df['Date'] < '2020')
eth_df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       Day of Week
# ...

# %%
filt = (eth_df['Date'] >= pd.to_datetime('2019-01-01')) & (eth_df['Date'] < pd.to_datetime('2020-01-01'))
eth_df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       Day of Week
# ...

# %%
eth_df.set_index('Date', inplace=True)

# %%
eth_df.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     Day of Week
# Date
# 2019-12-31 23:00:00     Tuesday
# ...

# %%
eth_df.loc['2020-01' : '2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                     Day of Week
# Date
# 2020-02-29 23:00:00    Saturday
# ...

# %%
eth_df.loc['2020-01' : '2020-02', 'Close']
# Out:
# Date
# 2020-02-29 23:00:00    217.31
# 2020-02-29 22:00:00    223.35
# 2020-02-29 21:00:00    223.48
# 2020-02-29 20:00:00    224.63
# 2020-02-29 19:00:00    225.31
#                         ...
# 2020-01-01 04:00:00    129.56
# 2020-01-01 03:00:00    129.57
# 2020-01-01 02:00:00    130.37
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.34
# Name: Close, Length: 1440, dtype: float64

# %%
eth_df.loc['2020-01' : '2020-02', 'Close'].mean()
# Out:
# 195.1655902777778

# %%
eth_df.loc['2020-01-01', 'High']
# Out:
# Date
# 2020-01-01 23:00:00    130.27
# 2020-01-01 22:00:00    131.41
# 2020-01-01 21:00:00    131.99
# 2020-01-01 20:00:00    131.87
# 2020-01-01 19:00:00    131.72
# 2020-01-01 18:00:00    132.14
# 2020-01-01 17:00:00    132.68
# 2020-01-01 16:00:00    132.56
# 2020-01-01 15:00:00    132.15
# 2020-01-01 14:00:00    132.05
# 2020-01-01 13:00:00    132.08
# 2020-01-01 12:00:00    131.31
# 2020-01-01 11:00:00    131.42
# 2020-01-01 10:00:00    130.33
# 2020-01-01 09:00:00    130.22
# 2020-01-01 08:00:00    130.01
# 2020-01-01 07:00:00    130.25
# 2020-01-01 06:00:00    130.25
# 2020-01-01 05:00:00    129.94
# 2020-01-01 04:00:00    130.00
# 2020-01-01 03:00:00    130.44
# 2020-01-01 02:00:00    130.50
# 2020-01-01 01:00:00    130.14
# 2020-01-01 00:00:00    128.54
# Name: High, dtype: float64

# %%
eth_df.loc['2020-01-01', 'High'].max()
# Out:
# 132.68

# %%
eth_df['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs = eth_df['High'].resample('D').max()
highs
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs.loc['2020-01-01']
# Out:
# 132.68

# %%
# %matplotlib inline

highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
eth_df.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
eth_df.resample('W').agg(
                            {
                                'Open'   : 'mean',
                                'High'   : 'max',
                                'Low'    : 'min',
                                'Close'  : 'mean',
                                'Volume' : 'sum'
                            }
                        )
# Out:
#                   Open    High     Low       Close        Volume
# Date
# 2017-07-02  268.066486  293.73  253.23  268.202162  8.084631e+07
# 2017-07-09  261.337024  285.00  231.25  261.062083  2.246746e+08
# 2017-07-16  196.193214  240.33  130.26  195.698393  5.017750e+08
# 2017-07-23  212.351429  249.40  153.25  212.783750  7.221637e+08
# 2017-07-30  203.496190  229.99  178.03  203.309524  2.657305e+08
# ...                ...     ...     ...         ...           ...
# 2020-02-16  255.021667  290.00  216.31  255.198452  3.912867e+08
# 2020-02-23  265.220833  287.13  242.36  265.321905  3.067838e+08
# 2020-03-01  236.720536  278.13  209.26  236.373988  3.693920e+08
# 2020-03-08  229.923571  253.01  196.00  229.817619  2.736569e+08
# 2020-03-15  176.937521  208.65   90.00  176.332821  4.983998e+08
#
# [142 rows x 5 columns]

# %% [markdown]
# ## Reading / Writing Data to different Sources

# %%
eth_weekly_data = eth_df.resample('W').agg(
                                                {
                                                    'Open'   : 'mean',
                                                    'High'   : 'max',
                                                    'Low'    : 'min',
                                                    'Close'  : 'mean',
                                                    'Volume' : 'sum'
                                                }
                                          )

# %%
eth_weekly_data
# Out:
#                   Open    High     Low       Close        Volume
# Date
# 2017-07-02  268.066486  293.73  253.23  268.202162  8.084631e+07
# 2017-07-09  261.337024  285.00  231.25  261.062083  2.246746e+08
# 2017-07-16  196.193214  240.33  130.26  195.698393  5.017750e+08
# 2017-07-23  212.351429  249.40  153.25  212.783750  7.221637e+08
# 2017-07-30  203.496190  229.99  178.03  203.309524  2.657305e+08
# ...                ...     ...     ...         ...           ...
# 2020-02-16  255.021667  290.00  216.31  255.198452  3.912867e+08
# 2020-02-23  265.220833  287.13  242.36  265.321905  3.067838e+08
# 2020-03-01  236.720536  278.13  209.26  236.373988  3.693920e+08
# 2020-03-08  229.923571  253.01  196.00  229.817619  2.736569e+08
# 2020-03-15  176.937521  208.65   90.00  176.332821  4.983998e+08
#
# [142 rows x 5 columns]

# %%
eth_weekly_data.to_csv('data/eth_weekly_data.csv')

# %%
eth_weekly_data.to_excel('data/eth_weekly_data.xlsx')

# %%
sample_data = pd.read_excel('data/eth_weekly_data.xlsx', index_col='Date')

# %%
sample_data
# Out:
#                   Open    High     Low       Close        Volume
# Date
# 2017-07-02  268.066486  293.73  253.23  268.202162  8.084631e+07
# 2017-07-09  261.337024  285.00  231.25  261.062083  2.246746e+08
# 2017-07-16  196.193214  240.33  130.26  195.698393  5.017750e+08
# 2017-07-23  212.351429  249.40  153.25  212.783750  7.221637e+08
# 2017-07-30  203.496190  229.99  178.03  203.309524  2.657305e+08
# ...                ...     ...     ...         ...           ...
# 2020-02-16  255.021667  290.00  216.31  255.198452  3.912867e+08
# 2020-02-23  265.220833  287.13  242.36  265.321905  3.067838e+08
# 2020-03-01  236.720536  278.13  209.26  236.373988  3.693920e+08
# 2020-03-08  229.923571  253.01  196.00  229.817619  2.736569e+08
# 2020-03-15  176.937521  208.65   90.00  176.332821  4.983998e+08
#
# [142 rows x 5 columns]

# %%
eth_weekly_data.to_json('data/eth_weekly_data.json')

# %%
sample_data = pd.read_json('data/eth_weekly_data.json')
sample_data
# Out:
#                   Open    High     Low       Close        Volume
# 2017-07-02  268.066486  293.73  253.23  268.202162  8.084631e+07
# 2017-07-09  261.337024  285.00  231.25  261.062083  2.246746e+08
# 2017-07-16  196.193214  240.33  130.26  195.698393  5.017750e+08
# 2017-07-23  212.351429  249.40  153.25  212.783750  7.221637e+08
# 2017-07-30  203.496190  229.99  178.03  203.309524  2.657305e+08
# ...                ...     ...     ...         ...           ...
# 2020-02-16  255.021667  290.00  216.31  255.198452  3.912867e+08
# 2020-02-23  265.220833  287.13  242.36  265.321905  3.067838e+08
# 2020-03-01  236.720536  278.13  209.26  236.373988  3.693920e+08
# 2020-03-08  229.923571  253.01  196.00  229.817619  2.736569e+08
# 2020-03-15  176.937521  208.65   90.00  176.332821  4.983998e+08
#
# [142 rows x 5 columns]

# %% [markdown]
# ###### Connecting to SQL Databases (PostgreSQL)

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://postgres:satanshubh@localhost:5432/MyFirstDB')

# %%
eth_weekly_data.to_sql('ETH_weekly_data', engine, if_exists = 'replace')
# Out:
# 142

# %%
sql_df = pd.read_sql('ETH_weekly_data', engine, index_col = 'Date')
sql_df
# Out:
#                   Open    High     Low       Close        Volume
# Date
# 2017-07-02  268.066486  293.73  253.23  268.202162  8.084631e+07
# 2017-07-09  261.337024  285.00  231.25  261.062083  2.246746e+08
# 2017-07-16  196.193214  240.33  130.26  195.698393  5.017750e+08
# 2017-07-23  212.351429  249.40  153.25  212.783750  7.221637e+08
# 2017-07-30  203.496190  229.99  178.03  203.309524  2.657305e+08
# ...                ...     ...     ...         ...           ...
# 2020-02-16  255.021667  290.00  216.31  255.198452  3.912867e+08
# 2020-02-23  265.220833  287.13  242.36  265.321905  3.067838e+08
# 2020-03-01  236.720536  278.13  209.26  236.373988  3.693920e+08
# 2020-03-08  229.923571  253.01  196.00  229.817619  2.736569e+08
# 2020-03-15  176.937521  208.65   90.00  176.332821  4.983998e+08
#
# [142 rows x 5 columns]

# %%
sql_df = pd.read_sql_query('SELECT * FROM ipl', engine) # i have a table ipl in my sql database 
sql_df
# Out:
#   team
# 0  CSK
# 1   MI
# 2  KKR
# 3  SRH
# 4   RR
# 5  RCB
# 6  LSG
# 7   GT
# 8   PK
# 9   DC
